# %% [markdown]
# __Importing the pandas as pd__

# %%
import pandas as pd

# %%
#imporing and assigning our dataset to a variable

url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'
df = pd.read_csv(url)
df.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2011-10-05         -4002          -4499.0           497 -1354.0
# 1  2011-10-12         -7397          -5842.0         -1555   512.0
# 2  2011-10-19         -3292          -3466.0           174  1399.0
# 3  2011-10-26         -3696          -2998.0          -698  2631.0
# 4  2011-12-07         -7956          -5761.0         -2196  1089.0
#
#    Total Bond  Taxable Bond  Municipal Bond    Total
# 0       -5828       -6258.0             430 -11184.0
# 1        3954        3927.0              28  -2931.0
# 2        5652        5102.0             550   3759.0
# 3        4910        4070.0             841   3846.0
# 4        3523        2068.0            1456  -3343.0

# %%
#5. Set the column Date as the index.
df = df.set_index('Date')
df.head()
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2011-10-05         -4002          -4499.0           497 -1354.0       -5828
# 2011-10-12         -7397          -5842.0         -1555   512.0        3954
# 2011-10-19         -3292          -3466.0           174  1399.0        5652
# 2011-10-26         -3696          -2998.0          -698  2631.0        4910
# 2011-12-07         -7956          -5761.0         -2196  1089.0        3523
#
#             Taxable Bond  Municipal Bond    Total
# Date
# 2011-10-05       -6258.0             430 -11184.0
# 2011-10-12        3927.0              28  -2931.0
# 2011-10-19        5102.0             550   3759.0
# 2011-10-26        4070.0             841   3846.0
# 2011-12-07        2068.0            1456  -3343.0

# %%
#6. What is the type of the index?
df.index
# Out:
# Index(['2011-10-05', '2011-10-12', '2011-10-19', '2011-10-26', '2011-12-07',
#        '2011-12-14', '2011-12-21', '2011-12-28', '2012-12-05', '2012-12-12',
#        ...
#        '2024-06-26', '2024-07-02', '2024-07-10', '2024-07-17', '2024-07-24',
#        '2024-12-04', '2024-12-11', '2024-12-18', '2024-12-24', '2024-12-31'],
#       dtype='object', name='Date', length=159)

# %%
#7. Set the index to a DatetimeIndex type

df.index = pd.to_datetime(df.index)

# %%
#8. Change the frequency to monthly, sum the values and assign it to monthly.
monthly = df.resample('M').sum()
monthly
# Out:
# C:\Users\ak\AppData\Local\Temp\ipykernel_9112\701888118.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = df.resample('M').sum()
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2011-10-31        -18387         -16805.0         -1582  3188.0        8688
# 2011-11-30             0              0.0             0     0.0           0
# 2011-12-31        -23657         -16659.0         -6999  2395.0       13817
# 2012-01-31             0              0.0             0     0.0           0
# 2012-02-29             0              0.0             0     0.0           0
# ...                  ...              ...           ...     ...         ...
# 2024-08-31             0              0.0             0     0.0           0
# 2024-09-30             0              0.0             0     0.0           0
# 2024-10-31             0              0.0             0     0.0           0
# ...

# %%
#9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.
monthly = monthly.dropna()
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2011-10-31        -18387         -16805.0         -1582  3188.0        8688
# 2011-11-30             0              0.0             0     0.0           0
# 2011-12-31        -23657         -16659.0         -6999  2395.0       13817
# 2012-01-31             0              0.0             0     0.0           0
# 2012-02-29             0              0.0             0     0.0           0
# ...                  ...              ...           ...     ...         ...
# 2024-08-31             0              0.0             0     0.0           0
# 2024-09-30             0              0.0             0     0.0           0
# 2024-10-31             0              0.0             0     0.0           0
# 2024-11-30             0              0.0             0     0.0           0
# 2024-12-31        148012              0.0        135741     0.0      124989
#
#             Taxable Bond  Municipal Bond   Total
# ...

# %%
#10. Good, now we have the monthly data. Now change the frequency to year.
year = monthly.resample('AS-JAN').sum()
year
# Out:
# C:\Users\ak\AppData\Local\Temp\ipykernel_9112\594985138.py:2: FutureWarning: 'AS-JAN' is deprecated and will be removed in a future version, please use 'YS-JAN' instead.
#   year = monthly.resample('AS-JAN').sum()
#             Total Equity  Domestic Equity  World Equity   Hybrid  Total Bond  \
# Date
# 2011-01-01        -42044         -33464.0         -8581   5583.0       22505
# 2012-01-01        -23929         -22012.0         -1915    785.0        9828
# 2013-01-01          8052          -5562.0         13615   4180.0      -24460
# 2014-01-01        -17011         -15124.0         -1887  -6141.0      -14400
# 2015-01-01        -36337         -25116.0        -11221 -12474.0      -28678
# 2016-01-01             0              0.0             0      0.0           0
# 2017-01-01        -51270         -54927.0          3657 -10514.0       26158
# 2018-01-01             0              0.0             0      0.0           0
# ...
